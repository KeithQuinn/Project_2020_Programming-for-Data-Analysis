# %% [markdown]
# # Project_2020_Programming-for-Data-Analysis
#
# ## *The Manufacturing of Medical Device Tubing*
# ***
#
# ## 1 Introduction
#
# The real world phenomenon considered for this project is the manufacturing of medical device tubing. There are two key concepts considered, both are researched, understood and explained, they are;
#
# - The Extrusion Process
# - Process Validation
#
# The plan for this notebook was to provide an overview of the extrusion process which is the process that manufactures the tubing and also an overview of process validation which provides the scientific evidence that the extrusion process is capable of consistently manufacturing the tubing.
#
# Having an appreciation of the extrusion process and of process validation the next step in this notebook is the manufacturing of an extruded tube through simulation. This is where a tube is brought through the extrusion process and validated using simulated data generated to represent the real world phenomenon. The process inputs and outputs are identified and investigated. Having an understanding of the process inputs and outputs, data is simulated to represent the likely distributions of the variables and to demonstrate their relationships with each other.
#
#
# ## 2 Extrusion Process Overview
#
# The extrusion process begins at the hopper of the machine. The polymer material in granulated form is loaded into the hopper and gravity fed onto the screw. The screw is situated within a barrel that is heated to a controlled temperature. The screw rotates and conveys the material along the barrel. As the material is conveyed it is heated and transformed from a granular state to a molten state. As the molten material leaves the barrel it is delivered through an assembly of tooling to an extrusion head. The purpose of the extrusion head is to provide a passage for the molten polymer to flow and to house the cone and die.  The cone and die creates the required shape of the product [1]. Refer to Figure 1 which is a cross section of the extruder, this shows the hopper, screw, heaters and barrel etc which have just been discussed.
#
# ![extruder.JPG](attachment:extruder.JPG)
#
# When the material exits from the extrusion head it is passed through a water bath for cooling. The extruded material is pulled at a constant rate from the extrusion head by a puller. The puller feeds the tube to a cutter which cuts the product to the required length. Before getting cut to length the material passes through a measurement system which is constantly measuring the required process outputs. The product is then transferred from the extrusion line via a conveyor [1]. Figure 2 provides an image of the extrusion line complete with downstream ancillary equipment.
#
# ![extruder_ancillary.png](attachment:extruder_ancillary.png)
# __*Figure 2: extrusion line with downstream ancillary equipment [2]*__
#
# There are two videos of the extrusion process provided below. The first video looks at the extruder only and the second video looks at the extrusion line and the ancillary equipment. These videos are for reference as it's important to understand the process before going any further;
#
# __*Note: If the video doesn't play on Github, right click on the link and open in new tab to play video*__
#
# [*__Extrusion Process Video 'Extruder Only'__*](https://www.youtube.com/watch?v=WaB-dsB1Kfk) [3]
#
# [*__Extrusion Process Video 'Extrusion line with ancillary equipment'__*](https://www.youtube.com/watch?v=wE_KTLlrdMA) [4]
#
#
# ### 2.1 Extrusion in the Medical Industry
#
# In the medical device industry extrusion is the process used to manufacture tubing. Tubing is a significant component in the medical device industry as it's used on all catheters used in peripheral intervention (PI) procedures.
#
# Peripheral intervention is a minimally invasive outpatient (same day) procedure used to treat peripheral artery disease, which causes plaque buildup in the arteries leading to the intestines, head, arms and most commonly the legs. Plaque buildup is also called atherosclerosis. It's with thanks to the advances in the extrusion process that this minimally invasive treatment is possible [5].
#
# Extruded tubing is used to manufacture the bi-lumen shaft and is an input to the balloon forming process used to manufacture the balloon, both the shaft and the balloon are part of the peripheral intervention catheter system in Figure 3.
#
# ![Catheter.png](attachment:Catheter.png)
# __*Figure 3: Peripheral Intervention Catheter System [6]*__

# %% [markdown]
# ## 3 Process Validation Overview
#
# Process validation is defined as the collection and evaluation of data, from the process design stage through commercial production, which establishes scientific evidence that a process is capable of consistently delivering quality product. Process validation involves a series of activities taking place over the lifecycle of the product and process [7].
#
# For this project process validation is split into three sections and a brief explanation of each is provided;
#
# - Product Design
# - Process Development
# - Process Validation Builds
#
# ### 3.1 Product Design
# At the product design stage, the research and development (R&D) team design the product. This involves designing and building concepts of predefined dimensions. These concepts go through rigorous testing to prove that the design is acceptable from a quality, safety and design for manufacturing standpoints.
#
# As part of testing, challenge builds are complete to challenge and test the limits of the design. At the end of product design, the part drawing which includes all the specifications is approved, released and handed over to the process development team. Figure 4 displays a part drawing of an extruded tube, this drawing includes a visual representation of the tube along with the required specifications [8].
#
# ![extruded%20tube%20drawing.png](attachment:extruded%20tube%20drawing.png)
# __*Figure 4: extruded tube drawing*__
#
# ### 3.2 Process Development
# At the process development (PD) stage, the manufacturing process is developed. The process inputs are identified and their relationship to the process outputs studied. Process windows are developed for each input while ensuring that the components can be manufactured within the drawing specification. For example, if the speed is found to be nominal 50[m/s] and a process window developed of +/-10[m/s] then the process can run anywhere between 40 – 60[m/s] while making acceptable components. Figure 5 shows a process window of temperature and pressure, the process settings can be anywhere in this window and produce quality parts. Going outside the process window and the parts exhibit various defects [9].
#
# ![Process%20Window.jpg](attachment:Process%20Window.jpg)
# __*Figure 5: process window*__
#
# ### 3.3 Process Validation Analysis
# At the process validation (PV) analysis stage the process is validated through the analysis of simulated data representative of running the extrusion line and collecting the data. That is the process is tested through various component builds using settings from the developed input process window. It’s important here that standard production variation is included in the builds, examples of variation include, different shifts, different operators and a different tooling. The performance of the process outputs relative to the print outputs is analysed. If the process outputs are tight relative to the specifications the process is highly capable and passes validation refer to Figure 6. This is scientific evidence that a process is capable of consistently delivering quality product [10].
#
# ![Process%20Capability.jpg](attachment:Process%20Capability.jpg)
# __*Figure 6: process capability*__

# %% [markdown]
# ## 4 Manufacturing of an Extruded Tube through Simulation
#
# Having an understanding of the extrusion process and process validation the next step is to simulate the manufacturing of an extruded tube. In order to achieve this it's necessary to research the extrusion process further to identify the process inputs, process outputs and their relationships. Simulated data representative of the process inputs and outputs is generated and discussed also.
#
# *__Note: Much of the extrusion information is not referenced as it is knowledge gathered through years of experience working on medical device extrusion processes, having the knowledge limits the amount of researching required for this section.__*
#
# ## 4.2 Inputs, Process & Outputs
#
# ![inputs-process-outputs.png](attachment:inputs-process-outputs.png)
# __*Figure 7: Inputs-Process-Outputs*__
#
# With any manufacturing process there are the inputs, the process and outputs to be considered, the extrusion process is no exception. Three critical inputs that are considered for the extrusion process are; barrel temperature, puller speed and screw speed [11]. The outputs are taken from the part drawing in Figure 4 of an extruded tube, this drawing includes outer diameter (OD), wall thickness and length. The inputs and outputs are discussed.
#
# ### 4.2.1 Process Inputs
#
# *__Barrel Temperature [C]__*
#
# It critical that the barrel temperatures are suitable for the process, different processes with require different temperatures, for example a polyethylene extrusion process requires less thermal energy to break intermolecular bonds than a polyamide extrusion process. If the temperature is too low the screw may not be able to rotate in the barrel, this could cause the extruder to alarm out in a best case scenario or snap the screw in a worst case scenario. If the temperature is too high the material degrades which impacts its performance. Given the wide range of possible extrusion processes, temperatures can vary from 100 to 350 degrees celcius. The temperature is controlled using proportional–integral–derivative (PID) controllers and the inputs are floating point numbers with two decimal places.
#
# See code that follows for the generation of a random barrel temperature input, also included is a randomly generated list of 5 temperatures defined as temperature profile. Most extruders require a temperature profile, that is different zones on the barrel require different temperature inputs, in the example below a profile having 5 zones is considered.

# %%
# Simulated data point for barrel temperature [C]
# Let's assume an extrusion process for PEBAX and the range is 200 - 240 [C]

import random
Barrel_Temp = round(random.uniform(200, 240),2) # round to 2 decimal places
print(f'Barrel Temperature is: {Barrel_Temp} Degrees Celcius')
print()
Barrel_Profile = [] # empty list to append to
for i in range(0,5): # for loop
    n = round(random.uniform(200, 240),2) # generates a random 
    Barrel_Profile.append(n) # appends to the list values
print(f'Barrel Profile is: {Barrel_Profile} Degrees Celcius')
# Out:
# Barrel Temperature is: 216.62 Degrees Celcius
#
# Barrel Profile is: [202.12, 237.03, 219.55, 203.67, 236.24] Degrees Celcius

# %% [markdown]
# *__Screw speed [RPM]__*
#
# The screw speed is the roational speed the screw rotates within the extruder barrel. As the screw rotates it conveys material forward through the barrel. This conveying of material controls the amount of material output, the faster the roation the higher the output and vice versa.
#
# Just like barrel speed, screw speed is dependent on the type of extrusion process, type of material, extruded tibe size etc. For example if there is a large tube manufactured on a small extruder (relatively speaking) the screw would be running very fast i.e. 100 rpm, but if there's a small tube manufactured on a large extruder (again relatively speaking) the screw would be running very slow i.e. 10 rpm.
#
# If the screw rotates too slow the extrusion line can pulse which is an inconsistent output, the result of this would be an inconsistent tube that would fail inspection for outside diameter. If the screw rotates too fast it can over shear the polymer material, this can lead to chain scission which impacts the mechanical properties of the material.
#
# Screw speed is controlled on through an inbuilt controller on the extruder and the input is a non-zero integer. See code that follows for the generation of a random screw speed input value.

# %%
# Simulated data point for screw speed [rpm]
# Let's assume an average size extruder and tube 40-60 [rpm]

screw_speed = random.randint(40, 60)
print(f'The screw speed is: {screw_speed} [rpm]')
# Out:
# The screw speed is: 45 [rpm]

# %% [markdown]
# *__Puller speed [mm/s]__*
#
# The puller speed is the speed at which the extrusion is pulled through the cooling tank, OD gauge and into the cutter, refer to Figure 2. The puller speed is important as it controls how the polymer chains are orientated as they enter the cooling tank. The orientation of the polymer chains is an important factor when considering mechanical properties. For example if the chains are fully aligned forming a high percentage crystallinity there may be high strength but low elongation/tensile properties, the tube may be brittle. If on the other hand the chains have time to relax before being entering the cooling tank then the tube will exhibit completely different mechanical properties such as ductility and toughness.
#
# The puller speed works closely with the screw speed often in closed loop control, this is because of the important relationshhip between the two. If the screw speed increased and the puller speed remained constant then the OD of the tube will increase, also is the screw speed stayed constant and the puller speed increased the OD of the tube would decrease. The process works on a fine balance of keeping the two in synchronisation in order to manufacture a tube with consistent outputs.
#
# As with barrel temperature and screw speed, puller speed is dependent on the process, thick walled extrusions would be pulled slower than thin walled at the same screw speed to get the desired output. If toughness and ductility is important the extrusion would be given time to relax before entering the cooling tank so this would require a slow puller speed. If the tube is to be hard wearing then it would be best to have the chains aligned to give a highly crystalline structure, this would be better achieved with a fast puller speed. The following code generates a random non zero integer as would be representative of the puller speed input.

# %%
# Simulated data point for puller [mm/s]
# Let's assume a puller speed window of of 180-220 [mm/s]

puller_speed = random.randint(180, 220)
print(f'The puller speed is: {puller_speed} [mm/s]')
# Out:
# The puller speed is: 219 [mm/s]

# %% [markdown]
# ### 4.2.2 Process Outputs
#
# For this project the part drawing of the extruded tube in Figure 4 is going to be used. From that drawing it can be seen that there are three outputs, there is also a process control output for a visual inspection;
#
# - Outer Diameter
# - Wall Thickness
# - Tube Length
# - Visual Inspection
#
# *__Outer Diameter [mm]__*
#
# The outer diameter is the diameter of the outside of the tube. As the tube passes through the laser gauge (refer to Figure 2) the OD is measured. It records continuous variable data having two decimal places. The data follows a normal distribution. An example dataset is generated in the following code. the data set assumes the nominal value from the drawing as the mean and assumes a standard deviation of 0.1 and 1000 values.
#
# *__Normal Distribution__*
#
# This is the first time normal distribution has been mentioned. A brief description of a normal distribution is provided.
#
# The normal distribution is the most important probability distribution in statistics because it fits many natural phenomena. For example, heights, blood pressure, measurement error, and IQ scores follow the normal distribution. It is also known as the Gaussian distribution and the bell curve.
#
# The normal distribution is a probability function that describes how the values of a variable are distributed. It is a symmetric distribution where most of the observations cluster around the central peak and the probabilities for values further away from the mean taper off equally in both directions. Extreme values in both tails of the distribution are similarly unlikely [12].

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

loc = 1.732 # mean
scale = 0.1 # standard deviation of 0.1 is assumed
size = 1000 # number of values

normal_data = np.random.normal(loc, scale, size) # generate a data set that follows a normal distribution

plt.figure(figsize=(10, 6)) # figure size
plt.title('Normal Distribution') # title
plt.suptitle('Extruded Tube Outer Diameter') # subtitle
plt.xlabel(f'Mean = {loc}mm, Std Dev = {scale}mm and total values = {size}') # xlabel
plt.ylabel('Occurrences') # ylabel
sns.distplot(a=normal_data, hist=True, kde=True, color='g')
txt="Figure 8: Tube OD" # create caption
plt.figtext(0.5, 0.01, txt, wrap=True, horizontalalignment='center', fontsize=10) # locate caption
plt.show() # show histogram

# %% [markdown]
# *__Wall Thickness [mm]__*
#
# The wall thickness of the tube is also measured as the tube passes through the laser gauge (refer to Figure 2). The OD and the ID are measured. The gauge is connected to a data processor which calculates the wall thickness based on the OD and ID. The formula is simply $ (OD-ID) / 2 $.
#
# Wall thickness is a 2 sided specification having continuous variable data to two decimal places. It follows a normal distribution. An example dataset is generated in the following code. The data set assumes the nominal value from the part drawing in Figure 4 as the mean and assumes a standard deviation of 0.1 and 1000 values.

# %%
loc = 0.187 # mean
scale = 0.1 # standard deviation
size = 1000 # number of values

normal_data = np.random.normal(loc, scale, size) # generate a data set that follows a normal distribution

plt.figure(figsize=(10, 6)) # figure size
plt.title('Normal Distribution') # title
plt.suptitle('Extruded Tube Wall Thickness') # subtitle
plt.xlabel(f'Mean = {loc}mm, Std Dev = {scale}mm and total values = {size}') # xlabel
plt.ylabel('Occurrences') # ylabel
sns.distplot(a=normal_data, hist=True, kde=True, color='r')
txt="Figure 9: Wall thickness" # create caption
plt.figtext(0.5, 0.01, txt, wrap=True, horizontalalignment='center', fontsize=10) # locate caption
plt.show() # show histogram

# %% [markdown]
# *__Tube Length [mm]__*
#
# The length of the tube is measured using a ruler that has 1mm increments. The data set consists of integer values and the specification is one sided per the part drawing in Figure 4. The data follows a Gumbel Distribution as a result of the one sided specification.
#
# *__Gumbel Distribution__*
#
# This is the first time Gumbel distribution has been mentioned. A brief description of the Gumbel distribution is provided.
#
# Gumbel distribution otherwise known as the extreme type I distribution has two forms. One is based on the smallest extreme and the other is based on the largest extreme. These are called the minimum and maximum cases, respectively. It is an asymmetric, extreme value distribution, used to model maximums and minimums. For example, the EVD Type I has been used to predict earthquakes, floods and other natural disasters, as well as modeling operational risk in risk management and the life of products that quickly wear out after a certain age [13]. Given that the length data has a one sided specification the result is right skewed that fits the Gumbel distribution.

# %%
loc = 210 # mean
scale = 5 # standard deviation
size = 1000 # number of values

length_data = np.random.gumbel(loc, scale, size).astype(int)
plt.figure(figsize=(10, 6)) # figure size
plt.title('Gumbel Distribution') # title
plt.suptitle('Extruded Tube Length') # subtitle
plt.xlabel(f'Mean = {loc}mm, Std Dev = {scale}mm and total values = {size}') # xlabel
plt.ylabel('Occurrences') # ylabel
sns.distplot(a=length_data, hist=True, kde=True, color='r')
txt="Figure 10: Length" # create caption
plt.figtext(0.5, 0.01, txt, wrap=True, horizontalalignment='center', fontsize=10) # locate caption
plt.show() # show histogram

# %% [markdown]
# *__Visual Inspection__*
#
# The visual inspection is completed using a vision system and involves a machine visually checking the parts for any defects such as a scratch or a tear. The results are pass or fail which generates an attribute dataset. The visual inspection is sampled in subgroups of 10 and in the example below 100 subgroups are considered with a probability of 80% chance of pass. The data follows a binomial distribution. A sample dataset is generated in the following code.
#
# *__Binomial Distribution__*
#
# This is the first time binomial distribution has been mentioned. A brief description of binomail distribution is provided.
#
# A binomial distribution can be thought of as simply the probability of a SUCCESS or FAILURE outcome in an experiment or survey that is repeated multiple times. The binomial is a type of distribution that has two possible outcomes (the prefix “bi” means two, or twice). For example, a coin toss has only two possible outcomes: heads or tails and taking a test could have two possible outcomes: pass or fail. If you purchase a lottery ticket, you’re either going to win money, or you aren’t. Basically, anything you can think of that can only be a success or a failure can be represented by a binomial distribution [14]

# %%
n = 10 # subgroup size
p = 0.80 # probability of heads or tails
size = 100 # number of subgroups

# Pass is True or 1
# Fail is False or 0

visual_data = np.random.binomial(n, p, size) # create a data set that fits a binomial distribution

plt.figure(figsize=(10, 6)) # figure size
sns.set(style="darkgrid") # set style
ax = sns.countplot(x=visual_data) # plot countplot
plt.title("Binomial Distribution") # title
plt.suptitle("Visual Inspection of Extruded Tube") # subtitle
plt.ylabel("") # ylabel
plt.xlabel(f'Number of Passes from {n} trials and {size} repeats') # xlabel
txt="Figure 11: Binomial Distribution." # create caption
plt.figtext(0.5, 0.01, txt, wrap=True, horizontalalignment='center', fontsize=10) # locate caption
plt.show() # show countplot

# %% [markdown]
# ## 4.3 Process Development
#
# With an understanding of the process inputs and outputs the next step is to undertand their relationships. This understanding is demonstrated through the simulated process development of the tube. In this section, data will be simulated that represents the first builds on the extrusion line.
#
# The plan is to simulate data that is representative of issues that can occur at this phase of the manufacturing process. Then the inputs will be adjusted until the process is at a stage where it's ready for process validation.
#
# For this section of the project the part drawing the extruded tube drawing from Figure 4 is used. This drawing has the specifications that will be used during process development. The goal here is to get a process that is centred between the upper and lower spec limits and has minimum spread (standard deviation).
#
# ### 4.3.1 Initial Builds
#
# The first step is to start extruding. Using existing tooling, historical knowledge from similar extrusion processes and best engineering practices the extrusion line is set up to manufacture the tube. The objective here is to target the specification centre point (nominal) from the part drawing. The extrusion line would be run for two hours. The data is collated, then analysed. Based on the results of the analysis the process development team will discuss if improvements are required and how these improvements are going to be achieved.
#
# For the initial builds the following process parameters are input;
#
# - Barrel Temperature: 220 degrees celcius across all zones of the profile
# - Screw Speed: 50 rpm
# - Puller Speed 200 mm/s
#
# Given these inputs the following code simulates data for the process outputs. The specifications from the tube part drawing in Figure 4 are used in this section for data analysis and to be used to simulate real life scenarios such as process issues and improvements. The outputs and their specifications are as follows;
#
# - OD; *__nominal__ = 1.707 [mm], __LSL__ = 1.707 [mm], __USL__ = 1.757 [mm]*
# - Wall Thickness; *__nominal__ = 0.174 [mm], __LSL__ = 0.187 [mm], __USL__ = 0.2 [mm]*
# - Length; *210 [mm] __minimum__*
# - Visual; *__pass/fail__*
#
# #### 4.3.1.1 Process Development Run 1 - Extruded Tube Outer Diameter Simulated Dataset

# %%
dev1_OD_loc = 1.732 # mean
dev1_OD_scale = 0.02 # standard deviation of 0.02 from initial run
dev1_OD_size = 1000 # number of values

dev1_OD_normal_data = np.random.normal(dev1_OD_loc, dev1_OD_scale, dev1_OD_size) # generate a data set that follows a normal distribution

plt.figure(figsize=(10, 6)) # figure size
plt.title('Process Development Run 1 - Normal Distribution') # title
plt.suptitle('Process Development Run 1 - Extruded Tube Outer Diameter') # subtitle
plt.axvline(x=1.707)
plt.axvline(x=1.732)
plt.axvline(x=1.757)
plt.xlabel(f'Mean = {dev1_OD_loc}mm, Std Dev = {dev1_OD_scale}mm and total values = {dev1_OD_size}') # xlabel
plt.ylabel('Occurrences') # ylabel
sns.distplot(a=dev1_OD_normal_data, hist=True, kde=True, color='g')
txt="Figure 12: Process Development Run 1 - Tube OD" # create caption
plt.figtext(0.5, 0.01, txt, wrap=True, horizontalalignment='center', fontsize=10) # locate caption
plt.show() # show histogram

# %% [markdown]
# #### 4.3.1.2 Process Development Run 1 - Extruded Tube Outer Diameter Simulated Dataset Discussion
#
# From Figure 12 above it is evident that the initial builds the process output for OD followed a normal distribution as expected. There are three lines included on the x-axis of the plot, these are the nominal (target), the lower specification limit (LSL) and the upper specification limit (USL).
#
# With reference to nominal it can be seen that the process ran very centred on the nominal which is a good result. The issues become apparent when the LSL and the USL are considered. It can be seen that the process runs outside specification a considerable amount of time. This type of process will not suffice for medical device manufacturing. Improvements are required for this process.
#
# To improve this process and to help reduce the spread (standard deviation) of the data the plan is to change the screw type. It is felt that a change of screw will produce a more consistent output which will reduce the spread of the data. A new data set will be generated representative of this change later in this report.
#
# #### 4.3.1.3 Process Development Run 1 - Extruded Tube Wall Thickness Simulated Dataset

# %%
dev1_wall_loc = 0.192 # mean
dev1_wall_scale = 0.001 # standard deviation
dev1_wall_size = 1000 # number of values

dev1_wall_normal_data = np.random.normal(dev1_wall_loc, dev1_wall_scale, dev1_wall_size) # generate a data set that follows a normal distribution

plt.figure(figsize=(10, 6)) # figure size
plt.title('Normal Distribution') # title
plt.suptitle('Process Development Run 1 - Extruded Tube Wall Thickness') # subtitle
plt.axvline(x=0.174)
plt.axvline(x=0.187)
plt.axvline(x=0.2)
plt.xlabel(f'Mean = {dev1_wall_loc}mm, Std Dev = {dev1_wall_scale}mm and total values = {dev1_wall_size}') # xlabel
plt.ylabel('Occurrences') # ylabel
sns.distplot(a=dev1_wall_normal_data, hist=True, kde=True, color='r')
txt="Figure 13: Process Development Run 1 - Extruded Tube Wall thickness" # create caption
plt.figtext(0.5, 0.01, txt, wrap=True, horizontalalignment='center', fontsize=10) # locate caption
plt.show() # show histogram

# %% [markdown]
# #### 4.3.1.4 Process Development Run 1 - Extruded Tube Wall Thickness Simulated Dataset Discussion
#
# From Figure 13 above it is evident that the initial builds the process output for wall thickness followed a normal distribution as expected. There are three lines included on the x-axis of the plot, these are the nominal (target), the lower specification limit (LSL) and the upper specification limit (USL).
#
# It can be seen that the process ran off centre on the low side of the specification. The good news for this output is that the standard deviation is low and the data is tightly grouped. To improve this output the wall needs to be reduced. By reducing the screw speed from 50rpm to 40rpm, this fix will reduce the extruder output and in so doing will reduce and centre the wall thickness. A new data set will be generated representative of this change later in this report.
#
# #### 4.3.1.5 Process Development Run 1 - Extruded Tube Length Simulated Dataset

# %%
dev1_len_loc = 215 # mean
dev1_len_scale = 5 # standard deviation
dev1_len_size = 1000 # number of values

dev1_len_length_data = np.random.gumbel(dev1_len_loc, dev1_len_scale, dev1_len_size).astype(int)
plt.figure(figsize=(10, 6)) # figure size
plt.title('Gumbel Distribution') # title
plt.suptitle('Process Development Run 1 - Extruded Tube Length') # subtitle
plt.axvline(x=210)
plt.xlabel(f'Mean = {dev1_len_loc}mm, Std Dev = {dev1_len_scale}mm and total values = {dev1_len_size}') # xlabel
plt.ylabel('Occurrences') # ylabel
sns.distplot(a=dev1_len_length_data, hist=True, kde=True, color='r')
txt="Figure 14: Process Development Run 1 - Extruded Tube Length" # create caption
plt.figtext(0.5, 0.01, txt, wrap=True, horizontalalignment='center', fontsize=10) # locate caption
plt.show() # show histogram

# %% [markdown]
# #### 4.3.1.6 Process Development Run 1 - Extruded Tube Length Simulated Dataset Discussion
# From Figure 14 above it is evident that the initial builds the process output for length followed a Gumbel distribution as expected. The minimum length specification of 210mm is included in the plot. It can be seen that the process had many out of specification data points. This process is not acceptable in the medical device industry and so improvements are required before moving into process validation.
#
# To improve this, the process input line speed will be increased which will increase the length of the tube before it is cut. There will also be some tooling modifications complete to minimise the spread of the data. A new data set will be generated representative of this change later in this report.
#
# #### 4.3.1.7 Process Development Run 1 - Extruded Tube Visual Inspection Simulated Dataset

# %%
dev1_vis_n = 10 # subgroup size
dev1_vis_p = 0.7 # probability of pass
dev1_vis_size = 100 # number of subgroups

# Pass is True or 1
# Fail is False or 0

dev1_visual_data = np.random.binomial(dev1_vis_n, dev1_vis_p, dev1_vis_size) # create a data set that fits a binomial distribution

plt.figure(figsize=(10, 6)) # figure size
sns.set(style="darkgrid") # set style
ax = sns.countplot(x=dev1_visual_data) # plot countplot
plt.title("Binomial Distribution") # title
plt.suptitle("Process Development Run 1 - Extruded Tube Visual Inspection") # subtitle
plt.ylabel("") # ylabel
plt.xlabel(f'Number of Passes from {dev1_vis_n} trials and {dev1_vis_size} repeats') # xlabel
txt="Figure 15: Process Development Run 1 - Extruded Tube Visual Inspection." # create caption
plt.figtext(0.5, 0.01, txt, wrap=True, horizontalalignment='center', fontsize=10) # locate caption
plt.show() # show countplot

# %% [markdown]
# #### 4.3.1.8 Process Development Run 1 - Extruded Tube Visual Inspection Simulated Dataset Discussion
#
# From Figure 15 above it is evident that the initial builds the process output for visual inspection followed a binomial distribution as expected. It can be seen that the sampling was in subgroups of 10 and there were 100 subgroups sampled. From the results it can be seen that there is room for improvement. The overall probability of getting 10 passed units in each sample of 10 was 70%.
#
# After investigation it was found that the inspection criteria for this output was overly stringent. There was further development done that reduced the inspection pass criteria for this output. For the next builds the new parts will be inspected to the new procedure, this should result in a lower scrap rate for visual defects.
#
# ### 4.3.2 Process Improvements Builds
#
# Having completed the initial process development builds and analysing the simulated data the team understand where the process needs to be improved.
#
# - For the OD a new screw has been purchased and is now fitted to the extruder to reduce the output variation, this should reduce the spread of the data.
# - For the wall thickness the screw speed has been reduced, this will reduce the output and centre the data around the nominal.
# - For the lenght specification the line speed is increased to increase the length, there has also been some tooling modifications to reduce the spread of the data.
# - For the visual inspection the inspection criteria has been updated, the initial criteria was over stringent and not practical for manufacturing.
#
# Data is now simulated that is representative of the aforementioned changes.
#
# #### 4.3.2.1 Process Development Run 2 - Extruded Tube Outer Diameter Simulated Dataset

# %%
dev2_OD_loc = 1.732 # mean
dev2_OD_scale = 0.005 # standard deviation of 0.02 from initial run
dev2_OD_size = 1000 # number of values

dev2_OD_normal_data = np.random.normal(dev2_OD_loc, dev2_OD_scale, dev2_OD_size) # generate a data set that follows a normal distribution

plt.figure(figsize=(10, 6)) # figure size
plt.title('Process Development Run 2 - Normal Distribution') # title
plt.suptitle('Process Development Run 2 - Extruded Tube Outer Diameter') # subtitle
plt.axvline(x=1.707)
plt.axvline(x=1.732)
plt.axvline(x=1.757)
plt.xlabel(f'Mean = {dev2_OD_loc}mm, Std Dev = {dev2_OD_scale}mm and total values = {dev2_OD_size}') # xlabel
plt.ylabel('Occurrences') # ylabel
sns.distplot(a=dev2_OD_normal_data, hist=True, kde=True, color='g')
txt="Figure 16: Process Development Run 2 - Tube OD" # create caption
plt.figtext(0.5, 0.01, txt, wrap=True, horizontalalignment='center', fontsize=10) # locate caption
plt.show() # show histogram

# %% [markdown]
# #### 4.3.2.2 Process Development Run 2 - Extruded Tube Outer Diameter Simulated Dataset Discussion
#
# From Figure 16 above it is evident that the process improvements have worked. The process output for OD followed a normal distribution as expected. There are three lines included on the x-axis of the plot, these are the nominal (target), the lower specification limit (LSL) and the upper specification limit (USL).
#
# With reference to nominal it can be seen that the process ran very centred which is a positive result. Along with being centred, the spread of the data has reduced resulting in a smaller standard deviation which is representative of an ideal process.
#
# This process output is now ready for process validation. A new simulated data set will be generated for the process validation later in this report.
#
# #### 4.3.2.3 Process Development Run 2 - Extruded Tube Wall Thickness Simulated Dataset

# %%
dev2_wall_loc = 0.187 # mean
dev2_wall_scale = 0.001 # standard deviation
dev2_wall_size = 1000 # number of values

dev2_wall_normal_data = np.random.normal(dev2_wall_loc, dev2_wall_scale, dev2_wall_size) # generate a data set that follows a normal distribution

plt.figure(figsize=(10, 6)) # figure size
plt.title('Normal Distribution') # title
plt.suptitle('Process Development Run 2 - Extruded Tube Wall Thickness') # subtitle
plt.axvline(x=0.174)
plt.axvline(x=0.187)
plt.axvline(x=0.2)
plt.xlabel(f'Mean = {dev2_wall_loc}mm, Std Dev = {dev2_wall_scale}mm and total values = {dev2_wall_size}') # xlabel
plt.ylabel('Occurrences') # ylabel
sns.distplot(a=dev2_wall_normal_data, hist=True, kde=True, color='r')
txt="Figure 17: Process Development Run 2 - Extruded Tube Wall thickness" # create caption
plt.figtext(0.5, 0.01, txt, wrap=True, horizontalalignment='center', fontsize=10) # locate caption
plt.show() # show histogram

# %% [markdown]
# #### 4.3.2.4 Process Development Run 2 - Extruded Tube Wall Thickness Simulated Dataset Discussion
#
# From Figure 17 above it is evident that the process improvements have worked. The process output for wall thickness followed a normal distribution as expected. There are three lines included on the x-axis of the plot, these are the nominal (target), the lower specification limit (LSL) and the upper specification limit (USL).
#
# With reference to nominal it can be seen that the process ran very centred which is a positive result. Along with being centred the spread of the data has remained tight resulting in a small standard deviation which is representative of an ideal process.
#
# This process output is now ready for process validation. A new simulated data set will be generated for the process validation later in this report.
#
# #### 4.3.2.5 Process Development Run 2 - Extruded Tube Length Simulated Dataset

# %%
dev2_len_loc = 230 # mean
dev2_len_scale = 4 # standard deviation
dev2_len_size = 1000 # number of values

dev2_len_length_data = np.random.gumbel(dev2_len_loc, dev2_len_scale, dev2_len_size).astype(int)
plt.figure(figsize=(10, 6)) # figure size
plt.title('Gumbel Distribution') # title
plt.suptitle('Process Development Run 2 - Extruded Tube Length') # subtitle
plt.axvline(x=210)
plt.xlabel(f'Mean = {dev2_len_loc}mm, Std Dev = {dev2_len_scale}mm and total values = {dev2_len_size}') # xlabel
plt.ylabel('Occurrences') # ylabel
sns.distplot(a=dev2_len_length_data, hist=True, kde=True, color='r')
txt="Figure 18: Process Development Run 2 - Extruded Tube Length" # create caption
plt.figtext(0.5, 0.01, txt, wrap=True, horizontalalignment='center', fontsize=10) # locate caption
plt.show() # show histogram

# %% [markdown]
# #### 4.3.2.6 Process Development Run 2 - Extruded Tube Length Simulated Dataset Discussion
#
# From Figure 18 above it is evident that the process improvements have worked. The process output for length followed a Gumbel distribution as expected. The minimum length specification of 210mm is included in the plot. It can be seen that the process has moved away from the LSL making this representative of an ideal process.
#
# This process output is now ready for process validation. A new simulated data set will be generated for the process validation later in this report.
#
# #### 4.3.2.7 Process Development Run 2 - Extruded Tube Visual Inspection Simulated Dataset

# %%
dev2_vis_n = 10 # subgroup size
dev2_vis_p = 0.85 # probability of pass
dev2_vis_size = 100 # number of subgroups

# Pass is True or 1
# Fail is False or 0

dev2_visual_data = np.random.binomial(dev2_vis_n, dev2_vis_p, dev2_vis_size) # create a data set that fits a binomial distribution

plt.figure(figsize=(10, 6)) # figure size
sns.set(style="darkgrid") # set style
ax = sns.countplot(x=dev2_visual_data) # plot countplot
plt.title("Binomial Distribution") # title
plt.suptitle("Process Development Run 2 - Extruded Tube Visual Inspection") # subtitle
plt.ylabel("") # ylabel
plt.xlabel(f'Number of Passes from {dev2_vis_n} trials and {dev2_vis_size} repeats') # xlabel
txt="Figure 19: Process Development Run 2 - Extruded Tube Visual Inspection." # create caption
plt.figtext(0.5, 0.01, txt, wrap=True, horizontalalignment='center', fontsize=10) # locate caption
plt.show() # show countplot

# %% [markdown]
# #### 4.3.2.8 Process Development Run 2 - Extruded Tube Visual Inspection Simulated Dataset Discussion
#
# From Figure 19 above it is evident that the process improvements have worked. The process output for visual inspection followed a binomial distribution as expected.
#
# From the results it can be seen that there was significant improvement. The overall probability of getting 10 passed units in each sample of 10 went from 70% to 85% making this process ready for process validation. A new simulated data set will be generated for the process validation later.

# %% [markdown]
# ## 4.4 Process Validation
#
# Now that the process is developed the next step is to validate the process. In this section of the report, simulated data is generated representative of process validation and in line with the process development section above.
#
# The process capability (Cpk) is also calculated for the variable outputs; OD, wall thickness and length. This calculated process capability is then compared to the requirements to pass the process validation, this scientific evidence is used to make a decision as to whether the process validation passes or fails.
#
# __*Process Capability (Cp and Cpk)*__
#
# Process capability is the repeatability and consistency of a manufacturing process relative to the customer requirements in terms of specification limits of a product parameter. This measure is used to objectively measure the degree to which your process is or is not meeting the requirements [15].
#
# Capability indices have been developed to graphically portray that measure. Capability indices let you place the distribution of your process in relation to the product specification limits. Capability indices should be used to determine whether the process, given its natural variation, is capable of meeting established specifications. It is also a measure of the manufacturability of the product with the given processes [15].
#
# Process capability can be expressed with an index. Assuming that the mean of the process is centered on the target value, the process capability index Cp can be used. Cp is a simple process capability index that relates the allowable spread of the spec limits (spec range or the difference between the upper spec limit, USL, and the lower specification limit, LSL) to the measure of the actual, or natural, variation of the process, represented by 6 sigma, where sigma is the estimated process standard deviation [15].
#
# Cpk measures not only the process variation with respect to allowable specifications, it also considers the location of the process average.
#
# Cpk is taken as the smaller of either Cpl or Cpu where
#
# Cpl = (X -LSL) / 3 sigma where X is the process mean
#
# Cpu = (USL – X) / 3 sigma where X is the process mean
#
# Many companies are establishing specific process capability targets. They may typically start with 1.33 for supplier qualification and have an expected goal of 2.0. If the process is near normal and in statistical control, Cpk can be used to estimate the expected percent of defective material [15].
#
# For this simulated process validation the assumption is that a Cpk value of 2.0 and above qualifies the process, anything less than a Cpk of 2.0 and the process fails validation.
#
# ### 4.4.1 Process Validation - Extruded Tube Outer Diameter Simulated Dataset

# %%
ProVal_OD_loc = 1.730 # mean
ProVal_OD_scale = 0.0035 # standard deviation of 0.02 from initial run
ProVal_OD_size = 1000 # number of values
OD_USL=1.757
OD_LSL=1.707

OD_Cpu = round((OD_USL - ProVal_OD_loc) / (3*ProVal_OD_scale),2)
OD_Cpl = round((ProVal_OD_loc - OD_LSL) / (3*ProVal_OD_scale),2)
OD_Cpk = np.min([OD_Cpu, OD_Cpl])

print(f' The upper capability index (Cpu) of the tube OD is {OD_Cpu}')
print(f' The lower capability index (Cpl) of the tube OD is {OD_Cpl}')
print(f' The lower of the two indices is the actual process capability (Cpk) of the tube OD has a value of {OD_Cpk}')
print('----------------------------------------------------------------------------------------')

ProVal_OD_normal_data = np.random.normal(ProVal_OD_loc, ProVal_OD_scale, ProVal_OD_size) # generate a data set that follows a normal distribution

plt.figure(figsize=(10, 6)) # figure size
plt.title('Process Validation - Normal Distribution') # title
plt.suptitle('Process Validation - Extruded Tube Outer Diameter') # subtitle
plt.axvline(x=OD_LSL)
plt.axvline(x=1.732)
plt.axvline(x=OD_USL)
plt.xlabel(f'Mean = {ProVal_OD_loc}mm, Std Dev = {ProVal_OD_scale}mm and total values = {ProVal_OD_size}') # xlabel
plt.ylabel('Occurrences') # ylabel
sns.distplot(a=ProVal_OD_normal_data, hist=True, kde=True, color='g')
txt="Figure 20: Process Validation - Tube OD" # create caption
plt.figtext(0.5, 0.01, txt, wrap=True, horizontalalignment='center', fontsize=10) # locate caption
plt.show() # show histogram
# Out:
#  The upper capability index (Cpu) of the tube OD is 2.57
#  The lower capability index (Cpl) of the tube OD is 2.19
#  The lower of the two indices is the actual process capability (Cpk) of the tube OD has a value of 2.19
# ----------------------------------------------------------------------------------------

# %% [markdown]
# ### 4.4.2 Process Validation - Extruded Tube Outer Diameter Simulated Dataset Discussion
#
# From Figure 20 above it can be seen that the process ran slightly off of centre and followed a normal distribution. The capability indices were calculated which quantifies how far off centre the process ran. The upper capability index was 2.57 and the lower was 2.19 indicative of the process running slightly off centre towards the LSL. The actual process capability is the lower of the two. Considering the requirement to pass the process validation was a Cpk of 2.0 or greater this process has passed validation and is ready to manufacture commercial product.
#
# ### 4.4.3 Process Validation - Extruded Tube Wall Thickness Simulated Dataset

# %%
ProVal_wall_loc = 0.187 # mean
ProVal_wall_scale = 0.002 # standard deviation
ProVal_wall_size = 1000 # number of values

Wall_USL=0.2 # upper spec limit
Wall_LSL=0.174 # lower spec limit

Wall_Cpu = round((Wall_USL - ProVal_wall_loc) / (3*ProVal_wall_scale),2)
Wall_Cpl = round((ProVal_wall_loc - Wall_LSL) / (3*ProVal_wall_scale),2)
Wall_Cpk = np.min([Wall_Cpu, Wall_Cpl])

print(f' The upper capability index (Cpu) of the tube Wall Thickness is {Wall_Cpu}')
print(f' The lower capability index (Cpl) of the tube Wall Thickness is {Wall_Cpl}')
print(f' The lower of the two indices is the actual process capability (Cpk) of the tube Wall Thickness has a value of {Wall_Cpk}')

ProVal_wall_normal_data = np.random.normal(ProVal_wall_loc, ProVal_wall_scale, ProVal_wall_size) # generate a data set that follows a normal distribution

plt.figure(figsize=(10, 6)) # figure size
plt.title('Normal Distribution') # title
plt.suptitle('Process Validation - Extruded Tube Wall Thickness') # subtitle
plt.axvline(x=Wall_LSL)
plt.axvline(x=0.187)
plt.axvline(x=Wall_USL)
plt.xlabel(f'Mean = {dev2_wall_loc}mm, Std Dev = {ProVal_wall_scale}mm and total values = {ProVal_wall_size}') # xlabel
plt.ylabel('Occurrences') # ylabel
sns.distplot(a=ProVal_wall_normal_data, hist=True, kde=True, color='r')
txt="Figure 21: Process Validation - Extruded Tube Wall thickness" # create caption
plt.figtext(0.5, 0.01, txt, wrap=True, horizontalalignment='center', fontsize=10) # locate caption
plt.show() # show histogram
# Out:
#  The upper capability index (Cpu) of the tube Wall Thickness is 2.17
#  The lower capability index (Cpl) of the tube Wall Thickness is 2.17
#  The lower of the two indices is the actual process capability (Cpk) of the tube Wall Thickness has a value of 2.17

# %% [markdown]
# ### 4.4.4 Process Validation - Extruded Tube Wall Thickness Simulated Dataset Discussion
# From Figure 21 above it can be seen that the process ran perfectly centered and followed a normal distribution. With reference to the Cpl and Cpu it can be seen that both are the same value which quantifies how centred the process ran. Considering the requirement to pass the process validation was a Cpk of 2.0 or greater this process has passed validation and is ready to manufacture commercial product.
#
# ### 4.4.5 Process Validation - Extruded Tube Length Simulated Dataset

# %%
ProVal_len_loc = 250 # mean
ProVal_len_scale = 3 # standard deviation
ProVal_len_size = 1000 # number of values

Len_LSL=210

Len_Cpl = round((ProVal_len_loc - Len_LSL) / (3*ProVal_len_scale),2)
Len_Cpk = Len_Cpl

print(f' The lower capability index (Cpl) of the tube Wall Thickness is {Len_Cpl}')
print(f' The lower of the two indices is the actual process capability (Cpk) of the tube Wall Thickness has a value of {Len_Cpk}')

ProVal_len_length_data = np.random.gumbel(ProVal_len_loc, ProVal_len_scale, ProVal_len_size).astype(int)

plt.figure(figsize=(10, 6)) # figure size
plt.title('Gumbel Distribution') # title
plt.suptitle('Process Validation - Extruded Tube Length') # subtitle
plt.axvline(x=Len_LSL)
plt.xlabel(f'Mean = {ProVal_len_loc}mm, Std Dev = {ProVal_len_scale}mm and total values = {ProVal_len_size}') # xlabel
plt.ylabel('Occurrences') # ylabel
sns.distplot(a=ProVal_len_length_data, hist=True, kde=True, color='r')
txt="Figure 22: Process Validation - Extruded Tube Length" # create caption
plt.figtext(0.5, 0.01, txt, wrap=True, horizontalalignment='center', fontsize=10) # locate caption
plt.show() # show histogram
# Out:
#  The lower capability index (Cpl) of the tube Wall Thickness is 4.44
#  The lower of the two indices is the actual process capability (Cpk) of the tube Wall Thickness has a value of 4.44

# %% [markdown]
# ### 4.4.6 Process Validation - Extruded Tube Length Simulated Dataset Discussion
#
# From Figure 22 above it can be seen that the length variable followed a Gumbel distribution as expected. For the process validation the target was moved from 230mm to 250mm while keeping tight control on the data on the LSL side. There wasn't the same tight controls on data that was greater than the target.
#
# There is a distribution free method which states that if the process capability (Cpk) is more than twice the requirement the distribution of the data doesn't matter. Given the requirement of a minimum Cpk of 2 and the actual simulated data Cpk of greater than 4 this process passes validation making it an highly capable process for medical device manufacturing.
#
# ### 4.4.7 Process Validation - Extruded Tube Visual Inspection Simulated Dataset

# %%
ProVal_vis_n = 10 # subgroup size
ProVal_vis_p = 0.95 # probability of pass
ProVal_vis_size = 10 # number of subgroups

# Pass is True or 1
# Fail is False or 0

ProVal_visual_data = np.random.binomial(ProVal_vis_n, ProVal_vis_p, ProVal_vis_size) # create a data set that fits a binomial distribution

plt.figure(figsize=(10, 6)) # figure size
sns.set(style="darkgrid") # set style
ax = sns.countplot(x=ProVal_visual_data) # plot countplot
plt.title("Binomial Distribution") # title
plt.suptitle("Process Validation - Extruded Tube Visual Inspection") # subtitle
plt.ylabel("") # ylabel
plt.xlabel(f'Number of Passes from {ProVal_vis_n} trials and {ProVal_vis_size} repeats') # xlabel
txt="Figure 23: Process Validation - Extruded Tube Visual Inspection." # create caption
plt.figtext(0.5, 0.01, txt, wrap=True, horizontalalignment='center', fontsize=10) # locate caption
plt.show() # show countplot

# %% [markdown]
# ### 4.4.7 Process Validation - Extruded Tube Visual Inspection Simulated Dataset Discussion
#
# The visual inspection isn't a drawing output so process validation is not required. As part of the process validation simualated data was generated and analysed. A good process should have a probability of 90% or greater of acceptable parts.From the validation runs the simulated data shows a 95% probability of acceptable parts. This means that out the the sample sizes of 10 there will be more often than not 9 or 10 good parts from 10. This is a process that will be handed over to the production team with a high level of confidence of manufaturing good parts.

# %% [markdown]
# ## Summary
#
# The real-world phenomenon considered for this project was the manufacturing of medical device tubing. There are two key parts of medical device manufacturing;
#
# - The Extrusion Process
# - Process Validation
#
# Before simulating data, it was felt necessary to provide an overview of the extrusion process and process validation.
#
# For the extrusion process an explanation of the extruder itself is provided, this is followed with an explanation of the overall process including the downstream ancillary equipment, images and video links are included to ensure the reader has an appreciation of the process. Finally, in this section an explanation of where extrusion is used and why it's important in the medical device industry.
#
# The next section provides a process validation overview. This section is broken into three main sections;
#
# - Product Design
# - Process Development
# - Process Validation Analysis
#
# With an understanding of the extrusion process and of process validation the next part of the project looks at the manufacturing of an extruded tube through simulation. This section starts off by identifying the process inputs and outputs and their relationships. The data types and typical distributions are discussed. Data in generated using the NumPy random function and plots of the distributions are provided and discussed.
#
# The product design is discussed, and the part drawing provided. The process is then developed through simulation. In the development section the dimensions, specifications and tolerances are used to test the process i.e. can parts be made that are in specification.
#
# In the first development runs there are some process issues, these issues result in data that is off-centred, data that has a huge spread (standard deviation) and data that has too many reject parts.
#
# Following this there are some adjustments made to the process and a second set of process development results are generated to simulate the process improvements that have been made, this data is then analysed using the part drawing specifications. The process changes result in improved data that proves the process is capable of manufacturing parts that are in specification.
#
# With the process looking good from a development standpoint, process validation is initiated. Once again simulated data is generated representative of the process for the validation.
#
# This data is then analysed in terms of process capability (Cpk). The results of the analysis determine if the process is capable enough to pass the validation. Passing the validation provides the scientific evidence required to manufacture medical device tubing for commercial use.

# %% [markdown]
# ## Conclusion
#
# This project was a good test in that it was more about finding a real world phenomenon and applying the learnings to it. To date the assignments and assessments have been more about writing code and completing a very defined problem. It took some time to come up with a real world phenomenon, I tried a few different ideas but initially I was over complicating the task and tying myself up in knots!
#
# After a few failed attempts I decided the best approach here was to go with something I'm familar with, so I started looking at options from my professional life. I decided to go with a manufaturing process as there are inputs, outputs and relationships between them. Having a good understanding of the process meant I understood the inputs and outputs, their relationships and the type of data associated with each. Importantly, I also know the typical distributions of the output data.
#
# The plan here was to provide an overview of the extrusion process and process validation. Then using NumPy random I'd simulate data that was representative of the extrusion process through the various stages an extrusion process must go before manufacturing commercial product such as design, development and validation.
#
# Overall I felt that this project worked out well and I'm happy with my attempt. The project took a good bit of time and effort but I feel it was time and effort well spent. For sure it was something a bit different than the previous assessments and assignments but it's good from a learnind and development standpoint to be looking at data analytics from different angles.

# %% [markdown]
# ## References
#
# [1] Plastics Technology; Profile Extrusion;
# https://www.ptonline.com/knowledgecenter/profile-extrusion/profile-extrusion-fundamentals/history-and-fundamentals-of-extrusion
#
# [2] Ian Major et al; The Influence of Low Shear Microbore Extrusion on the Properties of High Molecular Weight Poly(L-Lactic Acid) for Medical Tubing Applications;
# https://www.researchgate.net/publication/332511341_The_Influence_of_Low_Shear_Microbore_Extrusion_on_the_Properties_of_High_Molecular_Weight_PolyL-Lactic_Acid_for_Medical_Tubing_Applications
#
# [3] PaulsonTraining; Extruder Operation and Control - Paulson Training;
# https://www.youtube.com/watch?v=WaB-dsB1Kfk
#
# [4] Freelin Wade; How it is Made: Freelin-Wade Plastic Tubing Extrusion;
# https://www.youtube.com/watch?v=wE_KTLlrdMA
#
# [5] Mercy Health; Peripheral Vascular Intervention;
# https://www.mercyhealth.com/find-a-service-or-specialty/heart-and-vascular-care/vascular/procedures/peripheral-vascular-intervention
#
# [6] Boston Scientific; MUSTANG™ 0.035" Balloon Dilatation Catheter Brochure;
# https://www.bostonscientific.com/content/dam/bostonscientific/pi/portfolio-group/catheter-balloon/Mustang/Mustang%20Brochure.pdf
#
# [7] U.S. Department of Health and Human Services Food and Drug Administration; Process Validation: General Principles and Practices;
# https://www.fda.gov/files/drugs/published/Process-Validation--General-Principles-and-Practices.pdf
#
# [8] Cleverism; Research and Development (R&D) | Overview & Process;
# https://www.cleverism.com/rd-research-and-development-overview-process/
#
# [9] Eitzlmayr et al; Hot Melt Extrusion: Product and Process Development;
# https://www.researchgate.net/publication/286934210_Hot_Melt_Extrusion_Product_and_Process_Development
#
# [10] Taylor Enterprises; Methods and Tools for Process Validation;
# https://variation.com/methods-and-tools-for-process-validation/
#
# [11] Chamil Abeykoon; Single Screw Extrusion Control: A Comprehensive Review and Directions for
# Improvements;
# https://core.ac.uk/download/pdf/192115805.pdf
#
# [12] Statistics by Jim; Normal Distribution in Statistics;
# https://statisticsbyjim.com/basics/normaldistribution/#:~:text=The%20normal%20distribution%20is%20the,distribution%20and%20the%20bell%20curve.
#
# [13] Nist Sematech; Extreme Value Type I Distribution;
# https://www.itl.nist.gov/div898/handbook/eda/section3/eda366g.htm
#
# [14] Statistics How To; Binomial Distribution: Formula, What it is and How to use it;
# https://www.statisticshowto.com/probability-and-statistics/binomial-theorem/binomial-distribution-formula/
#
# [15] NPD Solutions; Process Capability and Product Design;
# https://www.npd-solutions.com/proccap.html

# %% [markdown]
# # End
