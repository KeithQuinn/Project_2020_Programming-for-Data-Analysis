# %% [markdown]
# # Project_2020_Programming-for-Data-Analysis
# ***
#
# ## Intoduction
#
# In this jupyter notebook we'll look at completing a process validation for a manufacturing process. The manufacturing process is an extrusion process which is used to manufacture medical device components.
#
# ### Extrusion Process Overview
# The extrusion process begins at the hopper end of the machine. The material (resin) is loaded into the hopper and gravity fed onto the screw. The screw is situated within a barrel that is heated to a controlled temperature. The screw rotates and conveys the resin along the barrel. As the resin is conveyed it is heated and transformed from a granular state to a molten state. As the molten resin leaves the barrel it is delivered through an assembly of tooling to an extrusion head. The purpose of the extrusion head is to provide a passage for the molten polymer to flow and to house the cone and die.  The cone and die creates the required shape of the product [1]. Refer to Figure 1 which is a cross section of the extruder, this shows the hopper, screw, heaters and barrel etc which have just been discussed.
#
# When the material exits from the extrusion head it is passed through a water bath for cooling. The extruded material is pulled at a constant rate from the extrusion head by a puller. The puller feeds the tube to a cutter which cuts the product to the required length. Before getting cut to length the material passes through a measurement system which is constantly measuring the required process outputs. The product is then transferred from the extrusion line via a conveyor [1]. Figure 2 provides an image of the extrusion line complete with downstream ancillary equipment for reference.
#
# There are two videos of the extrusion process provided below. The first video looks at the extruder only and the second video looks at the extrusion line inclusive of the ancillary equipment. These videos are for reference as it's important to understand the process before going any further;
#
# [*__Extrusion Process Video 'Extruder Only'__*](https://www.youtube.com/watch?v=WaB-dsB1Kfk) [2]
#
# [*__Extrusion Process Video 'Extrusion line with ancillary equipment'__*](https://www.youtube.com/watch?v=wE_KTLlrdMA) [3]

# %%
from IPython.display import Image
from IPython.core.display import HTML
Image(url= "https://www.substech.com/dokuwiki/lib/exe/fetch.php?w=&h=&cache=cache&media=polymer_extrusion.png")

# %% [markdown]
# __*Figure 1: cross section of extruder*__

# %%
Image(url= "https://www.researchgate.net/profile/Ian_Major2/publication/332511341/figure/fig2/AS:749049678422019@1555598768952/Schematic-of-tube-extrusion-process-including-an-extruder-and-down-stream-ancillary.png", height=550, width =750)

# %% [markdown]
# __*Figure 2: extrusion line with downstream ancillary equipment [4]*__

# %% [markdown]
# ### Extrusion in the Medical Industry
#
# In the medical device industry extrusion is the process used to manufacture tubing. Tubing is a sugnificant component in the medical device industry as it's used on all stent delivery catheters used in interventional cardiology (IC) and peripheral interventional (PI) procedures.
#
# Extruded tubing is used to manufacture the bi-lumen shaft and is an input to the balloon forming process used to manufacture the balloon, both the shaft and the balloon are part of the peripheral intervention catheter system in Figure 3.
#
# Peripheral intervention is a minimally invasive outpatient (same day) procedure used to treat peripheral artery disease, which causes plaque buildup in the arteries leading to the intestines, head, arms and most commonly the legs. Plaque buildup is also called atherosclerosis. It's with thanks to the advances in the extrusion process that this minimally invasive treatment is possible [5].

# %%
Image(url= "https://www.bostonscientific.com/en-IN/products/catheters-balloon/Mustang_Balloon_Dilatation_Catheter/_jcr_content/maincontent-par/image_1.img.mustang_schematic-overview_960x229_eu.png")

# %% [markdown]
# __*Figure 3: Peripheral Intervention Catheter System [6]*__

# %%
Image(url= "https://pxt.azureedge.net/blob/e644eb8aa2a44b1732aca811f598ab695b43420a/static/courses/csintro/algorithms/inputs-process-outputs.png")

# %% [markdown]
# __*Figure 4: Inputs Process Outputs [6]*__
#
# ## Inputs, Process & Outputs
#
# With any manufacuring there are the inputs, the process and the outputs to be considered, the extrusion process is no exception. For this project there will be three process inputs and four process outputs considered, they are;
#
# __Process Inputs:__
#
# - Line speed [m/s]
# - Die temperature [C]
# - Melt pump speed [rpm]
#
#
# __Process:__
#
# - Medical device extrusion
#
# __Process Outputs:__
#
# - Outer diameter
# - Wall thickness
# - Length
# - Tactile and Visual
#
# Another important consideration is the component specifications. Having the process outputs is one thing but the specifications are required to provide the size and tolerance to which the component must be manufactured, without these there's no way of knowing what size the component needs to be, we must define how long a piece of string must be!
#
# The specifications are defined by the research and development team who provide a component drawing to the manufacturing team. This drawing will be then used to develop and vaidate the process. A typical drawing for an extruded tube in provided in Figure 5. This drawing shows specifications and tolerances for outer diameter, wall thickness and length. The importance of this drawing will become apparent when discussing process validation later.
#
# ![extruded%20tube%20drawing.png](attachment:extruded%20tube%20drawing.png)
#
# __*Figure 5: extruded tube drawing*__

# %% [markdown]
# ## References
#
# [1] Plastics Technology; Profile Extrusion; https://www.ptonline.com/knowledgecenter/profile-extrusion/profile-extrusion-fundamentals/history-and-fundamentals-of-extrusion
#
# [2] PaulsonTraining; Extruder Operation and Control - Paulson Training; https://www.youtube.com/watch?v=WaB-dsB1Kfk
#
# [3] Freelin Wade; How it is Made: Freelin-Wade Plastic Tubing Extrusion; https://www.youtube.com/watch?v=wE_KTLlrdMA
#
# [4] Ian Major et al; The Influence of Low Shear Microbore Extrusion on the Properties of High Molecular Weight Poly(L-Lactic Acid) for Medical Tubing Applications; https://www.researchgate.net/publication/332511341_The_Influence_of_Low_Shear_Microbore_Extrusion_on_the_Properties_of_High_Molecular_Weight_PolyL-Lactic_Acid_for_Medical_Tubing_Applications
#
# [5] Mercy Health; Peripheral Vascular Intervention; https://www.mercyhealth.com/find-a-service-or-specialty/heart-and-vascular-care/vascular/procedures/peripheral-vascular-intervention
#
# [6] Boston Scientific; MUSTANG™ 0.035" Balloon Dilatation Catheter Brochure; https://www.bostonscientific.com/content/dam/bostonscientific/pi/portfolio-group/catheter-balloon/Mustang/Mustang%20Brochure.pdf

# %% [markdown]
# # End
